# %% [markdown]
# ### 당뇨병 특성(BMI) 추출 및 데이터 분할 모델 훈련

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)


diabetes = load_diabetes()
X_raw = diabetes.data
y_raw = diabetes.target

X_bmi = X_raw[:, [2]]

# 데이터 분할
X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(
    X_bmi, y_raw,
    test_size=0.2,
    random_state=42
)

# 모델 훈련
mission_model = LinearRegression()
mission_model.fit(X_train_b, y_train_b)

y_pred = mission_model.predict(X_test_b)

mae_b = mean_absolute_error(y_test_b, y_pred)
mse_b = mean_squared_error(y_test_b, y_pred)
rmse_b = np.sqrt(mse_b)
r2_b = r2_score(y_test_b, y_pred)

print(f"당뇨병 BMI 선형회귀 평가결과:")
print(f"MAE: {mae_b}")
print(f"MSE: {mse_b}")
print(f"RMSE: {rmse_b}")
print(f"R2 Score: {r2_b}")

plt.scatter(X_test_b, y_test_b, color='black', label='실제 데이터')
plt.plot(X_test_b, y_pred, color='red', label='예측값 회귀선')
plt.legend()
plt.title('BMI지수에 따른 당뇨병 진행률 예측')
plt.xlabel('BMI')
plt.ylabel('당뇨병 진행 정도')
# Out:
# 당뇨병 BMI 선형회귀 평가결과:
# MAE: 52.25997644534553
# MSE: 4061.8259284949268
# RMSE: 63.73245584860925
# R2 Score: 0.23335039815872138
# Text(0, 0.5, '당뇨병 진행 정도')
