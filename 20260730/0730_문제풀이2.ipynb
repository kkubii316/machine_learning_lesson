# %% [markdown]
# # 데이터 전처리 EX-2 : 중복 데이터 제거

# %%
import pandas as pd

# 1. 가짜 데이터 생성
data = {
    'ProductID': [101, 102, 103, 104, 101, 102, 103, 105, 106, 101],
    'ProductName': ['A', 'B', 'C', 'D', 'A', 'B', 'C', 'E', 'F', 'A'],
    'Price': [100, 200, 300, 400, 100, 200, 300, 500, 600, 100],
    'Quantity': [1, 2, 3, 4, 1, 2, 3, 5, 6, 1]
}

# 2. DataFrame 생성
df = pd.DataFrame(data)

# 3. 중복된 데이터를 일부 추가 (중복된 행 4개 추가)
df.loc[len(df.index)] = [101, 'A', 100, 1]  # 중복 행 추가
df.loc[len(df.index)] = [102, 'B', 200, 2]  # 중복 행 추가
df.loc[len(df.index)] = [103, 'C', 300, 3]  # 중복 행 추가
df.loc[len(df.index)] = [104, 'D', 400, 4]  # 중복 행 추가

# 4. CSV 파일로 내보내기
df.to_csv('sales.csv', index=False)

print("sales.csv 파일이 생성되었습니다.")
# Out:
# sales.csv 파일이 생성되었습니다.

# %%
df = pd.read_csv('sales.csv')

# %%
print("===================데이터===================")
print(df)
print("===============중복 데이터 개수===============")
print(df.duplicated().sum())
print("===============중복 데이터 내용===============")
print(df[df.duplicated()])
# Out:
# ===================데이터===================
#     ProductID ProductName  Price  Quantity
# 0         101           A    100         1
# 1         102           B    200         2
# 2         103           C    300         3
# 3         104           D    400         4
# 4         101           A    100         1
# 5         102           B    200         2
# 6         103           C    300         3
# 7         105           E    500         5
# 8         106           F    600         6
# 9         101           A    100         1
# 10        101           A    100         1
# 11        102           B    200         2
# 12        103           C    300         3
# 13        104           D    400         4
# ===============중복 데이터 개수===============
# 8
# ===============중복 데이터 내용===============
#     ProductID ProductName  Price  Quantity
# 4         101           A    100         1
# 5         102           B    200         2
# 6         103           C    300         3
# 9         101           A    100         1
# 10        101           A    100         1
# 11        102           B    200         2
# 12        103           C    300         3
# 13        104           D    400         4

# %%
df_cleared = df.drop_duplicates(keep=False)

print("=========중복 데이터 제거 후=========")
print(df_cleared)
print("==========남의 데이터의 개수==========")
print(df_cleared.shape[0])
# Out:
# =========중복 데이터 제거 후=========
#    ProductID ProductName  Price  Quantity
# 7        105           E    500         5
# 8        106           F    600         6
# ==========남의 데이터의 개수==========
# 2
